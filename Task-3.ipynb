# %% [markdown]
# # The Sparks Foundation GRIP - JAN 2022

# %% [markdown]
# # Role - Data Science and Business Analytics Intern

# %% [markdown]
# # Task 3 = Exploratory Data Analysis-Retail(Level-Beginner)

# %% [markdown]
# ## Problem statement : Perform 'Exploratory Data Analysis' on dataset 'SampleSuperStore'

# %% [markdown]
# ## Dataset link = https://bit.ly/3i4rbWl

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import dataset

# %%
data=pd.read_csv(r'C:\Users\Rutuja Muthe\Downloads\The sparks foundation\SampleSuperstore.csv')
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Getting the information of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.sample(5)
# Out:
#            Ship Mode      Segment        Country         City       State  \
# 1568        Same Day     Consumer  United States  Los Angeles  California
# 8440    Second Class  Home Office  United States     Columbus        Ohio
# 4713  Standard Class     Consumer  United States   Huntsville       Texas
# 7846  Standard Class     Consumer  United States    Arlington    Virginia
# 5450  Standard Class  Home Office  United States       Olathe      Kansas
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 1568        90004     West  Office Supplies        Paper   122.970         3
# 8440        43229     East  Office Supplies        Paper    10.584         3
# 4713        77340  Central        Furniture  Furnishings    56.568         2
# 7846        22204    South       Technology       Phones  1871.880        12
# 5450        66062  Central  Office Supplies      Binders   331.960         2
#
#       Discount    Profit
# 1568       0.0   60.2553
# ...

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#checking for null values
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Relationship Analysis

# %%
corelation = data.corr()
sns.heatmap(corelation,xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True,cmap='Blues')

# %% [markdown]
# We look that there is strong correlation between Profit and Sales.

# %%
sns.pairplot(data)

# %%
sns.distplot(data['Sales'])

# %%
sns.distplot(data['Profit'])

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category',data=data)
# Out:
# <BarContainer object of 9994 artists>

# %% [markdown]
# From the above graph we can understand the different products in the three categories.

# %%
data.groupby('Sub-Category')['Profit','Sales'].agg(sum).plot.bar()
plt.title('Profit and Sales across Sub-Categories')
# Out:
# <ipython-input-16-456cb1b127ee>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Sub-Category')['Profit','Sales'].agg(sum).plot.bar()
# Text(0.5, 1.0, 'Profit and Sales across Sub-Categories')

# %% [markdown]
# From the above graph,the Profit of Copiers are high,and the Sales of Chairs & Phones are high among the others.

# %%
data['Cost'] = data['Sales'] - data['Profit']
data['Profit %'] = (data['Profit']/data['Cost'])/100

# %%
Profit_data = data.sort_values(['Profit %','Sub-Category'], ascending= False), data.groupby('Profit %')

# %%
plt.rcParams['figure.figsize'] = (10,5)
sns.distplot(data['Sales'],kde = False)
plt.title("Distribution of Sales")
plt.xlabel("Range of sales")
plt.ylabel("No. of Sales Count")
plt.show()

# %% [markdown]
# # Thank you...
